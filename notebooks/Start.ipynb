# %% [markdown]
# # Pandas for association rule mining
#
# I created this algorithm at https://github.com/FlightDataServices/carmine before which has been discontinued. I want to re-create it here

# %%
import pandas as pd
import seaborn as sns
from itertools import combinations

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
df = df.drop(columns=["alive"])

# %%
for x in ["age", "fare"]:
    df[x] = pd.qcut(df[x],10).astype(str)

# %%
y_col = "survived"
feature_cols = [x for x in df.columns if x != y_col]

# %%
for col in feature_cols:
    df[col] = "(" + str(col) + " = " + df[col].astype(str) + ")"

# %%
df.head()
# Out:
#    survived        pclass             sex                   age        sibsp  \
# 0         0  (pclass = 3)    (sex = male)  (age = (19.0, 22.0])  (sibsp = 1)
# 1         1  (pclass = 1)  (sex = female)  (age = (36.0, 41.0])  (sibsp = 1)
# 2         1  (pclass = 3)  (sex = female)  (age = (25.0, 28.0])  (sibsp = 0)
# 3         1  (pclass = 1)  (sex = female)  (age = (31.8, 36.0])  (sibsp = 1)
# 4         0  (pclass = 3)    (sex = male)  (age = (31.8, 36.0])  (sibsp = 0)
#
#          parch                       fare        embarked            class  \
# 0  (parch = 0)    (fare = (-0.001, 7.55])  (embarked = S)  (class = Third)
# 1  (parch = 0)  (fare = (39.688, 77.958])  (embarked = C)  (class = First)
# 2  (parch = 0)     (fare = (7.854, 8.05])  (embarked = S)  (class = Third)
# 3  (parch = 0)  (fare = (39.688, 77.958])  (embarked = S)  (class = First)
# 4  (parch = 0)     (fare = (7.854, 8.05])  (embarked = S)  (class = Third)
#
#              who            adult_male          deck  \
# 0    (who = man)   (adult_male = True)  (deck = nan)
# 1  (who = woman)  (adult_male = False)    (deck = C)
# 2  (who = woman)  (adult_male = False)  (deck = nan)
# 3  (who = woman)  (adult_male = False)    (deck = C)
# 4    (who = man)   (adult_male = True)  (deck = nan)
#
#                    embark_town            alone
# 0  (embark_town = Southampton)  (alone = False)
# 1    (embark_town = Cherbourg)  (alone = False)
# 2  (embark_town = Southampton)   (alone = True)
# 3  (embark_town = Southampton)  (alone = False)
# 4  (embark_town = Southampton)   (alone = True)

# %%
N = df.shape[0]
supp_y = df[y_col].mean()

# %%
def create_column_combinations(columns, limit=2):
    """
    Returns all possible column combinations up to limit.
    """
    combintaion_list = []
    for i in range(1,limit+1):
        combintaion_list += list(combinations(columns,i))
    return combintaion_list

# create_column_combinations(feature_cols,2)

# %%
def rule_miner(df, limit=2):
    """
    uses pandas groupby for association rule mining
    """
    results = []
    for combination in create_column_combinations(feature_cols,limit):
        _df = df.groupby(combination)[y_col].agg(["count","mean"]).reset_index()
        _df["itemset"] = _df.iloc[:,:-2].sum(axis=1)
        _df = _df.iloc[:,-3:]
        results.append(_df)
        
    df_total = pd.concat(results,axis=0).reset_index(drop=True)

    
    df_total = df_total.rename(columns={"mean": "confidence(X,Y)", "count":"count(X)"})
    df_total["support(X)"] = df_total["count(X)"] / N
    df_total["lift(X,Y)"] = df_total["confidence(X,Y)"] / supp_y
    df_total = df_total[['itemset','count(X)', 'support(X)', 'confidence(X,Y)', 'lift(X,Y)']]
    return df_total

# %%
test= rule_miner(df, limit=3)
# Out:
# C:\Users\e.cemal\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#   import sys

# %%
test
# Out:
#                                                  itemset  count(X)  \
# 0                                           (pclass = 1)       216
# 1                                           (pclass = 2)       184
# 2                                           (pclass = 3)       491
# 3                                         (sex = female)       314
# 4                                           (sex = male)       577
# ...                                                  ...       ...
# 14776  (deck = nan)(embark_town = Cherbourg)(alone = ...        57
# 14777  (deck = nan)(embark_town = Queenstown)(alone =...        18
# 14778  (deck = nan)(embark_town = Queenstown)(alone =...        55
# 14779  (deck = nan)(embark_town = Southampton)(alone ...       184
# 14780  (deck = nan)(embark_town = Southampton)(alone ...       332
#
#        support(X)  confidence(X,Y)  lift(X,Y)
# 0        0.242424         0.629630   1.640351
# 1        0.206510         0.472826   1.231836
# 2        0.551066         0.242363   0.631418
# 3        0.352413         0.742038   1.933205
# 4        0.647587         0.188908   0.492155
# ...           ...              ...        ...
# 14776    0.063973         0.315789   0.822715
# 14777    0.020202         0.333333   0.868421
# 14778    0.061728         0.400000   1.042105
# 14779    0.206510         0.375000   0.976974
# 14780    0.372615         0.204819   0.533608
#
# [14781 rows x 5 columns]

# %%
results = []
for combination in create_column_combinations(feature_cols,2):
    _df = df.groupby(combination)[y_col].agg(["count","mean"]).reset_index()
    _df["itemset"] = _df.iloc[:,:-2].sum(axis=1)
    _df = _df.iloc[:,-3:]

    results.append(_df)
#     _df.columns = ["itemset", "count", "confidence"]
    
# results
# _df.columns = ["itemset", "count", "confidence"]
# _df["support"] = _df["count"] / N # this can be done at the end
# _df
# Out:
# C:\Users\e.cemal\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Interpreting tuple 'by' as a list of keys, rather than a single key. Use 'by=[...]' instead of 'by=(...)'. In the future, a tuple will always mean a single key.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_total = pd.concat(results,axis=0).reset_index(drop=True)
# _df["itemset"] = _df.iloc[:,:-2].sum(axis=1)
# _df

# %%
df_total = df_total.rename(columns={"mean": "confidence(X,Y)", "count":"count(X)"})
df_total["support(X)"] = df_total["count(X)"] / N
df_total["lift(X,Y)"] = df_total["confidence(X,Y)"] / supp_y
df_total = df_total[['itemset','count(X)', 'support(X)', 'confidence(X,Y)', 'lift(X,Y)']]

# %%
df_total
# Out:
#                                          itemset  count(X)  support(X)  \
# 0                                   (pclass = 1)       216    0.242424
# 1                                   (pclass = 2)       184    0.206510
# 2                                   (pclass = 3)       491    0.551066
# 3                                 (sex = female)       314    0.352413
# 4                                   (sex = male)       577    0.647587
# ...                                          ...       ...         ...
# 1476   (embark_town = Queenstown)(alone = False)        20    0.022447
# 1477    (embark_town = Queenstown)(alone = True)        57    0.063973
# 1478  (embark_town = Southampton)(alone = False)       251    0.281706
# 1479   (embark_town = Southampton)(alone = True)       393    0.441077
# 1480           (embark_town = nan)(alone = True)         2    0.002245
#
#       confidence(X,Y)  lift(X,Y)
# 0            0.629630   1.640351
# 1            0.472826   1.231836
# 2            0.242363   0.631418
# 3            0.742038   1.933205
# 4            0.188908   0.492155
# ...               ...        ...
# 1476         0.350000   0.911842
# 1477         0.403509   1.051247
# 1478         0.462151   1.204026
# 1479         0.256997   0.669546
# 1480         1.000000   2.605263
#
# [1481 rows x 5 columns]

# %%
df_total[df_total["count(X)"]>200].sort_values("lift(X,Y)",ascending=False)
# Out:
#                                  itemset  count(X)  support(X)  \
# 297          (sex = female)(who = woman)       271    0.304153
# 1374   (who = woman)(adult_male = False)       271    0.304153
# 49                         (who = woman)       271    0.304153
# 3                         (sex = female)       314    0.352413
# 300   (sex = female)(adult_male = False)       314    0.352413
# ...                                  ...       ...         ...
# 1334          (class = Third)(who = man)       319    0.358025
# 183      (pclass = 3)(adult_male = True)       319    0.358025
# 176              (pclass = 3)(who = man)       319    0.358025
# 1388             (who = man)(deck = nan)       438    0.491582
# 1427     (adult_male = True)(deck = nan)       438    0.491582
#
#       confidence(X,Y)  lift(X,Y)
# 297          0.756458   1.970771
# 1374         0.756458   1.970771
# 49           0.756458   1.970771
# 3            0.742038   1.933205
# 300          0.742038   1.933205
# ...               ...        ...
# 1334         0.119122   0.310345
# 183          0.119122   0.310345
# 176          0.119122   0.310345
# 1388         0.114155   0.297404
# 1427         0.114155   0.297404
#
# [88 rows x 5 columns]
